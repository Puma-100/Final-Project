# %%
import pandas as pd

# File path
file_path = '/home/marshal/protonotebook/Data Mining/Nature-language/Sports_and_Outdoors_5.json'

# Read JSON file into DataFrame
data = pd.read_json(file_path, lines=True)
data.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin    reviewerName  \
# 0        5      True   06 3, 2015  A180LQZBUWVOLF  0000032034      Michelle A
# 1        1      True   04 1, 2015   ATMFGKU5SVEYY  0000032034       Crystal R
# 2        5      True  01 13, 2015  A1QE70QBJ8U6ZG  0000032034  darla Landreth
# 3        5      True  12 23, 2014  A22CP6Z73MZTYU  0000032034        L. Huynh
# 4        4      True  12 15, 2014  A22L28G8NRNLLN  0000032034         McKenna
#
#                                           reviewText  \
# 0            What a spectacular tutu! Very slimming.
# 1  What the heck? Is this a tutu for nuns? I know...
# 2                  Exactly what we were looking for!
# 3  I used this skirt for a Halloween costume and ...
# 4  This is thick enough that you can't see throug...
#
#                                              summary  unixReviewTime style  \
# 0                                         Five Stars      1433289600   NaN
# ...

# %% [markdown]
# Amazon Sports and Outdoors Products Dataset Review

# %%
review_data = data[['overall','reviewerID','reviewText','summary']]
review_data.head()
# Out:
#    overall      reviewerID                                         reviewText  \
# 0        5  A180LQZBUWVOLF            What a spectacular tutu! Very slimming.
# 1        1   ATMFGKU5SVEYY  What the heck? Is this a tutu for nuns? I know...
# 2        5  A1QE70QBJ8U6ZG                  Exactly what we were looking for!
# 3        5  A22CP6Z73MZTYU  I used this skirt for a Halloween costume and ...
# 4        4  A22L28G8NRNLLN  This is thick enough that you can't see throug...
#
#                                              summary
# 0                                         Five Stars
# 1                          Is this a tutu for nuns?!
# 2                                         Five Stars
# 3  I liked that the elastic waist didn't dig in (...
# 4  This is thick enough that you can't see throug...

# %%
review_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2839940 entries, 0 to 2839939
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   overall     int64
#  1   reviewerID  object
#  2   reviewText  object
#  3   summary     object
# dtypes: int64(1), object(3)
# memory usage: 86.7+ MB

# %%
print(review_data.overall.value_counts(normalize=True))
# Out:
# overall
# 5    0.676563
# 4    0.174487
# 3    0.074021
# 1    0.039141
# 2    0.035788
# Name: proportion, dtype: float64

# %% [markdown]
# #### we can see that most of our review are good but we also have bad reviews as well

# %%
filtered_data = review_data.drop_duplicates(subset=['reviewerID'])
filtered_data
# Out:
#          overall      reviewerID  \
# 0              5  A180LQZBUWVOLF
# 1              1   ATMFGKU5SVEYY
# 2              5  A1QE70QBJ8U6ZG
# 3              5  A22CP6Z73MZTYU
# 4              4  A22L28G8NRNLLN
# ...          ...             ...
# 2775517        5  A2F3EN7LN17C6G
# 2777195        5  A1XD8656MPLLCO
# 2793076        5   ANJRXC0VX93YD
# 2795943        5  A3LAWQC4XQ2M17
# 2795944        5  A25J46VKDFI2IJ
#
#                                                 reviewText  \
# 0                  What a spectacular tutu! Very slimming.
# 1        What the heck? Is this a tutu for nuns? I know...
# 2                        Exactly what we were looking for!
# 3        I used this skirt for a Halloween costume and ...
# 4        This is thick enough that you can't see throug...
# ...                                                    ...
# 2775517                                 Works as expected!
# 2777195    As described. easy to assemble with shock cord.
# ...

# %% [markdown]
# #### Eliminating Duplicates

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 332447 entries, 0 to 2795944
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   overall     332447 non-null  int64
#  1   reviewerID  332447 non-null  object
#  2   reviewText  332310 non-null  object
#  3   summary     332388 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 12.7+ MB

# %%
filtered_data_text = review_data.drop_duplicates(subset=['reviewerID'])
filtered_data_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 332447 entries, 0 to 2795944
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   overall     332447 non-null  int64
#  1   reviewerID  332447 non-null  object
#  2   reviewText  332310 non-null  object
#  3   summary     332388 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 12.7+ MB

# %% [markdown]
# From this analysis we can say that using reviewerID and reviewText give use same results above.

# %%
filtered_data_text
# Out:
#          overall      reviewerID  \
# 0              5  A180LQZBUWVOLF
# 1              1   ATMFGKU5SVEYY
# 2              5  A1QE70QBJ8U6ZG
# 3              5  A22CP6Z73MZTYU
# 4              4  A22L28G8NRNLLN
# ...          ...             ...
# 2775517        5  A2F3EN7LN17C6G
# 2777195        5  A1XD8656MPLLCO
# 2793076        5   ANJRXC0VX93YD
# 2795943        5  A3LAWQC4XQ2M17
# 2795944        5  A25J46VKDFI2IJ
#
#                                                 reviewText  \
# 0                  What a spectacular tutu! Very slimming.
# 1        What the heck? Is this a tutu for nuns? I know...
# 2                        Exactly what we were looking for!
# 3        I used this skirt for a Halloween costume and ...
# 4        This is thick enough that you can't see throug...
# ...                                                    ...
# 2775517                                 Works as expected!
# 2777195    As described. easy to assemble with shock cord.
# ...

# %%
filtered_data_text.to_csv('Sports_and_Outdoors_5_filtered.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Here I am download filtered_data for simplicity
